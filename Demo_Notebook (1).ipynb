# %% [markdown]
# ## Welcome to UC Berkeley

# %% [markdown]
# <table border="1" class="dataframe table table-striped">
#       <tr style="text-align: right;">
#       <td>Year</td>
#       <td>Undergrad Enrollment</td>
#       <td>Grad Enrollment</td>
#       <td>Asian Percentage</td>
#       <td>White Percentage</td>
#       <td>Hispanic/Latino Percentage</td>
#       <td>Black/African American Percentage</td>
#     </tr>
#     <tr>
#       <td>2015</td>
#       <td>27000</td>
#       <td>10000</td>
#       <td>32</td>
#       <td>30</td>
#       <td>14</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2016</td>
#       <td>27500</td>
#       <td>10500</td>
#       <td>33</td>
#       <td>29</td>
#       <td>15</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2017</td>
#       <td>28000</td>
#       <td>11000</td>
#       <td>34</td>
#       <td>28</td>
#       <td>16</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2018</td>
#       <td>28500</td>
#       <td>11500</td>
#       <td>35</td>
#       <td>27</td>
#       <td>16</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>2019</td>
#       <td>29000</td>
#       <td>12000</td>
#       <td>36</td>
#       <td>26</td>
#       <td>17</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>2020</td>
#       <td>29500</td>
#       <td>12500</td>
#       <td>37</td>
#       <td>25</td>
#       <td>17</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>2021</td>
#       <td>30000</td>
#       <td>13000</td>
#       <td>38</td>
#       <td>24</td>
#       <td>18</td>
#       <td>5</td>
#     </tr>
# </table>

# %% [markdown]
# #### Learn more about Campanile

# %% [markdown]
# ![](attachment:f2f2b4ad-e519-4039-a963-94b934aa9101.jpg)

# %% [markdown]
# #####

# %% [markdown]
# ![Berkeley_logo.png](attachment:95c981df-2afa-468d-a38a-b5f9d7d93958.png)
